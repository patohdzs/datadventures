# %% [markdown]
# # **Getting them stonks: Portfolio mean-variance optimization**
# ### Patricio Hernandez Senosiain
# ---

# %% [markdown]
# ## Contents:
#
# >[1 - Introduction](#1---Introduction)
# >
# >[2 - Importing dependencies](#2---Importing-dependencies)
# >
# >[3 - Data retrieval and exploratory analysis](#3---Data-retrieval-and-exploratory-analysis)
# >
# >[4 - Data cleaning and preprocessing](#4---Data-cleaning-and-preprocessing)
# >
# >[5 - Modelling](#5---Modelling)
# >
# >[6 - Conclusion](#6---Conclusion)
# >

# %% [markdown]
# ## 1 - Introduction

# %% [markdown]
# 1. Present aim
# 2. Explain Theory (mean-variance optimization)
# 3. Get data (summary stats)
# 4. Plot Efficient frontier + portfolio points (MC simulation)
# 5. Change parameters
# 6. Extensions

# %% [markdown]
# ### Aim: Given a selection of assets, what is the optimal allocation of these within a

# %% [markdown]
# ### $$ \textrm{min}\; w^T\sigma w \;\textrm{s.t.}\; \lambda R^Tw$$

# %% [markdown]
# ## 2 - Importing dependencies

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 3 - Data retrieval and exploratory analysis

# %%
# Specify asset symbols
stocks = ['IEC','CSTL','HLT', 'BABA','PINS','TWLO']
test = data.DataReader(stocks, 'yahoo', start='2020/01/01', end='2021/02/10')
test.head()
# Out:
# Attributes Adj Close                                                \
# Symbols          IEC       CSTL         HLT        BABA       PINS
# Date
# 2020-01-02      9.39  33.820000  111.279236  219.770004  18.799999
# 2020-01-03      9.15  33.020000  109.821472  217.000000  18.360001
# 2020-01-06      9.12  35.529999  109.252342  216.639999  18.910000
# 2020-01-07      9.26  34.369999  108.124077  217.630005  19.260000
# 2020-01-08      9.40  33.009998  109.042671  218.000000  19.719999
#
# Attributes             Close                                     ...  \
# Symbols           TWLO   IEC       CSTL         HLT        BABA  ...
# Date                                                             ...
# 2020-01-02  103.150002  9.39  33.820000  111.449997  219.770004  ...
# 2020-01-03  103.519997  9.15  33.020000  109.989998  217.000000  ...
# 2020-01-06  107.459999  9.12  35.529999  109.419998  216.639999  ...
# 2020-01-07  108.059998  9.26  34.369999  108.290001  217.630005  ...
# 2020-01-08  109.389999  9.40  33.009998  109.209999  218.000000  ...
#
# Attributes        Open                                      Volume            \
# Symbols            HLT        BABA       PINS        TWLO      IEC      CSTL
# Date
# 2020-01-02  111.150002  216.600006  18.799999  100.010002  23400.0   38800.0
# 2020-01-03  110.000000  216.350006  18.600000  101.099998  21700.0  127300.0
# 2020-01-06  109.019997  214.889999  18.270000  102.739998  72100.0  125800.0
# 2020-01-07  109.269997  217.639999  18.879999  107.629997  22600.0  114300.0
# 2020-01-08  108.139999  216.600006  19.250000  108.800003  39100.0  149800.0
#
# Attributes
# Symbols           HLT        BABA       PINS       TWLO
# Date
# 2020-01-02  2014600.0  15873500.0  6334600.0  2876700.0
# 2020-01-03  1854500.0   8604500.0  5203200.0  2502800.0
# 2020-01-06  1821800.0  11885500.0  7978900.0  3938700.0
# 2020-01-07  1498900.0   9388000.0  7471500.0  2643800.0
# 2020-01-08  2741600.0  11959100.0  7363500.0  3035000.0
#
# [5 rows x 36 columns]

# %% [markdown]
# ## 5 - Modelling

# %% [markdown]
# ## 6 - Conclusion
