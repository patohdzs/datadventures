# %% [markdown]
# # **Getting them stonks: Portfolio mean-variance optimaization**
# ---

# %% [markdown]
# ## Contents:
#
# >[1 - Introduction](#1---Introduction)
# >
# >[2 - Importing dependencies](#2---Importing-dependencies)
# >
# >[3 - Data retrieval and exploratory analysis](#3---Data-retrieval-and-exploratory-analysis)
# >
# >[4 - Data cleaning and preprocessing](#4---Data-cleaning-and-preprocessing)
# >
# >[5 - Modelling](#5---Modelling)
# >
# >[6 - Conclusion](#6---Conclusion)
# >

# %% [markdown]
# ## 1 - Introduction

# %% [markdown]
# 1. Present aim
# 2. Explain Theory (mean-variance optimization)
# 3. Get data (summary stats)
# 4. Plot Efficient frontier + portfolio points (MC simulation)
# 5. Change parameters
# 6. Extensions

# %% [markdown]
# # Aim: Given a selection of $n$ assets, what is the optimal allocation of these within a portfolio?

# %% [markdown]
# ### Mathematically:
# ### $ \underset{w}{\text{min}} \quad  w^T\:\Sigma \: w \quad \textrm{s.t}\quad  r^T\!w = \mu \;, \quad w^T\!\mathbb{1}=1$
# ### where:
#
# ### $w=\begin{bmatrix}
# w_1\\
# \vdots \\
# w_n
# \end{bmatrix} \quad,\quad r=\begin{bmatrix}
# \mathbb{E}[R_1]\\
# \vdots \\
# \mathbb{E}[R_n]
# \end{bmatrix} \quad,\quad\Sigma = \begin{bmatrix}
# \sigma_{11} & \dots & \sigma_{n1}\\
# \vdots & \ddots & \vdots\\
# \sigma_{1n} & \dots & \sigma_{nn}
# \end{bmatrix} \quad,\quad \mathbb{1}=\begin{bmatrix}
# 1\\
# \vdots \\
# 1
# \end{bmatrix}$

# %% [markdown]
# ## 2 - Importing dependencies

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 3 - Data retrieval and exploratory analysis

# %% [markdown]
# We focus our attention on [Investopedia's Top Stocks for March 2021](https://www.investopedia.com/top-stocks-4581225)

# %%
# Specify asset symbols
stocks = ['NRG','BIO','VIRT','WTM','ALL','MAT','FCX','IAC','ZM','CE','MRNA','PTON','ETSY','TSLA','ZS']
data = web.DataReader(stocks, 'yahoo', start='2020/01/01', end='2021/02/10')
data.head()
# Out:
# Attributes  Adj Close                                                         \
# Symbols           NRG         BIO       VIRT          WTM         ALL    MAT
# Date
# 2020-01-02  37.159161  372.160004  15.453154  1121.527832  110.420639  13.30
# 2020-01-03  36.584541  366.779999  15.813854  1119.320557  110.430420  13.48
# 2020-01-06  35.799213  372.029999  15.320263  1118.881104  110.753410  14.07
# 2020-01-07  35.310780  380.540009  15.272803  1110.760986  109.804039  14.18
# 2020-01-08  35.301205  381.790009  15.291789  1114.196899  110.107437  14.13
#
# Attributes                                        ...     Volume              \
# Symbols           FCX IAC         ZM          CE  ...        MAT         FCX
# Date                                              ...
# 2020-01-02  13.151219 NaN  68.720001  117.754089  ...  3288500.0  22771700.0
# 2020-01-03  12.752698 NaN  67.279999  116.154030  ...  2928400.0  20401300.0
# 2020-01-06  12.802513 NaN  70.320000  114.873993  ...  4184200.0  19145300.0
# 2020-01-07  13.001774 NaN  71.900002  114.427917  ...  8298600.0  20849500.0
# 2020-01-08  13.131293 NaN  72.550003  113.535767  ...  3304000.0  17484700.0
#
# Attributes                                                             \
# Symbols    IAC         ZM         CE       MRNA       PTON       ETSY
# Date
# 2020-01-02 NaN  1315500.0   911300.0  1233600.0  5916200.0  2152300.0
# 2020-01-03 NaN  1127900.0   770900.0  1751000.0  4974100.0  2109800.0
# 2020-01-06 NaN  3151600.0   710900.0  1606500.0  4028900.0  2077100.0
# 2020-01-07 NaN  6985400.0  1231300.0  1461400.0  3072000.0  1945500.0
# 2020-01-08 NaN  2482300.0   826300.0  1041600.0  7474100.0  3222700.0
#
# Attributes
# Symbols            TSLA         ZS
# Date
# 2020-01-02   47660500.0  1377200.0
# 2020-01-03   88892500.0  1165200.0
# 2020-01-06   50665000.0  1534600.0
# 2020-01-07   89410500.0  1714900.0
# 2020-01-08  155721500.0  3232500.0
#
# [5 rows x 90 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 280 entries, 2020-01-02 to 2021-02-10
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, NRG)   280 non-null    float64
#  1   (Adj Close, BIO)   280 non-null    float64
#  2   (Adj Close, VIRT)  280 non-null    float64
#  3   (Adj Close, WTM)   280 non-null    float64
#  4   (Adj Close, ALL)   280 non-null    float64
#  5   (Adj Close, MAT)   280 non-null    float64
#  6   (Adj Close, FCX)   280 non-null    float64
#  7   (Adj Close, IAC)   155 non-null    float64
#  8   (Adj Close, ZM)    280 non-null    float64
#  9   (Adj Close, CE)    280 non-null    float64
#  10  (Adj Close, MRNA)  280 non-null    float64
#  11  (Adj Close, PTON)  280 non-null    float64
#  12  (Adj Close, ETSY)  280 non-null    float64
#  13  (Adj Close, TSLA)  280 non-null    float64
#  14  (Adj Close, ZS)    280 non-null    float64
#  15  (Close, NRG)       280 non-null    float64
#  16  (Close, BIO)       280 non-null    float64
#  17  (Close, VIRT)      280 non-null    float64
#  18  (Close, WTM)       280 non-null    float64
#  19  (Close, ALL)       280 non-null    float64
#  20  (Close, MAT)       280 non-null    float64
#  21  (Close, FCX)       280 non-null    float64
#  22  (Close, IAC)       155 non-null    float64
#  23  (Close, ZM)        280 non-null    float64
#  24  (Close, CE)        280 non-null    float64
#  25  (Close, MRNA)      280 non-null    float64
#  26  (Close, PTON)      280 non-null    float64
#  27  (Close, ETSY)      280 non-null    float64
#  28  (Close, TSLA)      280 non-null    float64
#  29  (Close, ZS)        280 non-null    float64
#  30  (High, NRG)        280 non-null    float64
#  31  (High, BIO)        280 non-null    float64
#  32  (High, VIRT)       280 non-null    float64
#  33  (High, WTM)        280 non-null    float64
#  34  (High, ALL)        280 non-null    float64
#  35  (High, MAT)        280 non-null    float64
#  36  (High, FCX)        280 non-null    float64
#  37  (High, IAC)        155 non-null    float64
#  38  (High, ZM)         280 non-null    float64
#  39  (High, CE)         280 non-null    float64
#  40  (High, MRNA)       280 non-null    float64
#  41  (High, PTON)       280 non-null    float64
#  42  (High, ETSY)       280 non-null    float64
#  43  (High, TSLA)       280 non-null    float64
#  44  (High, ZS)         280 non-null    float64
#  45  (Low, NRG)         280 non-null    float64
#  46  (Low, BIO)         280 non-null    float64
#  47  (Low, VIRT)        280 non-null    float64
#  48  (Low, WTM)         280 non-null    float64
#  49  (Low, ALL)         280 non-null    float64
#  50  (Low, MAT)         280 non-null    float64
#  51  (Low, FCX)         280 non-null    float64
#  52  (Low, IAC)         155 non-null    float64
#  53  (Low, ZM)          280 non-null    float64
#  54  (Low, CE)          280 non-null    float64
#  55  (Low, MRNA)        280 non-null    float64
#  56  (Low, PTON)        280 non-null    float64
#  57  (Low, ETSY)        280 non-null    float64
#  58  (Low, TSLA)        280 non-null    float64
#  59  (Low, ZS)          280 non-null    float64
#  60  (Open, NRG)        280 non-null    float64
#  61  (Open, BIO)        280 non-null    float64
#  62  (Open, VIRT)       280 non-null    float64
#  63  (Open, WTM)        280 non-null    float64
#  64  (Open, ALL)        280 non-null    float64
#  65  (Open, MAT)        280 non-null    float64
#  66  (Open, FCX)        280 non-null    float64
#  67  (Open, IAC)        155 non-null    float64
#  68  (Open, ZM)         280 non-null    float64
#  69  (Open, CE)         280 non-null    float64
#  70  (Open, MRNA)       280 non-null    float64
#  71  (Open, PTON)       280 non-null    float64
#  72  (Open, ETSY)       280 non-null    float64
#  73  (Open, TSLA)       280 non-null    float64
#  74  (Open, ZS)         280 non-null    float64
#  75  (Volume, NRG)      280 non-null    float64
#  76  (Volume, BIO)      280 non-null    float64
#  77  (Volume, VIRT)     280 non-null    float64
#  78  (Volume, WTM)      280 non-null    float64
#  79  (Volume, ALL)      280 non-null    float64
#  80  (Volume, MAT)      280 non-null    float64
#  81  (Volume, FCX)      280 non-null    float64
#  82  (Volume, IAC)      155 non-null    float64
#  83  (Volume, ZM)       280 non-null    float64
#  84  (Volume, CE)       280 non-null    float64
#  85  (Volume, MRNA)     280 non-null    float64
#  86  (Volume, PTON)     280 non-null    float64
#  87  (Volume, ETSY)     280 non-null    float64
#  88  (Volume, TSLA)     280 non-null    float64
#  89  (Volume, ZS)       280 non-null    float64
# dtypes: float64(90)
# memory usage: 199.1 KB

# %%
data = data['Adj Close']
data.head()
# Out:
# Symbols           NRG         BIO       VIRT          WTM         ALL    MAT  \
# Date
# 2020-01-02  37.159161  372.160004  15.453154  1121.527832  110.420639  13.30
# 2020-01-03  36.584541  366.779999  15.813854  1119.320557  110.430420  13.48
# 2020-01-06  35.799213  372.029999  15.320263  1118.881104  110.753410  14.07
# 2020-01-07  35.310780  380.540009  15.272803  1110.760986  109.804039  14.18
# 2020-01-08  35.301205  381.790009  15.291789  1114.196899  110.107437  14.13
#
# Symbols           FCX  IAC         ZM          CE       MRNA   PTON  \
# Date
# 2020-01-02  13.151219  NaN  68.720001  117.754089  19.230000  29.74
# 2020-01-03  12.752698  NaN  67.279999  116.154030  18.889999  30.60
# 2020-01-06  12.802513  NaN  70.320000  114.873993  18.129999  29.75
# 2020-01-07  13.001774  NaN  71.900002  114.427917  17.780001  30.40
# 2020-01-08  13.131293  NaN  72.550003  113.535767  17.980000  29.65
#
# Symbols          ETSY       TSLA         ZS
# Date
# 2020-01-02  45.189999  86.052002  47.330002
# 2020-01-03  44.900002  88.601997  47.380001
# 2020-01-06  44.834999  90.307999  48.700001
# 2020-01-07  45.779999  93.811996  48.400002
# 2020-01-08  45.005001  98.428001  50.750000

# %% [markdown]
# ## 5 - Modelling

# %% [markdown]
# ## 6 - Conclusion
